# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../data/ny_mta_hourly_ridership.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9569818 entries, 0 to 9569817
# Data columns (total 4 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   transit_timestamp   object
#  1   station_complex_id  int64
#  2   ridership           float64
#  3   transfers           float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 292.0+ MB

# %%
df["timestamp"] = pd.to_datetime(df["transit_timestamp"])
df["date"] = df["timestamp"].dt.date
df["time"] = df["timestamp"].dt.time
df.drop(columns="transit_timestamp", inplace=True)

# %%
df.groupby([df["timestamp"].dt.year, df["timestamp"].dt.month])["ridership"].sum().plot()
# Out:
# <Axes: xlabel='timestamp,timestamp'>

# %%
df["date"] = df["timestamp"]
df["time"] = df["timestamp"]
